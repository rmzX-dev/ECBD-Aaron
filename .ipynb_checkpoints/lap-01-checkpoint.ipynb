# %%
import pandas as pd

# %%
datos = {
    "usuario" : ["Ana", "Luis", "Martha", "Carolina", "Sofia", "Pedro", "Elena", "Diego"],
    "edad" : [22, 35, 28, 40, 19, 31, 26, 45],
    "ciudad" : ["CDMX", "Monterrey", "Guadalajara", "Puebla", "Cancún", "Merida", "Tijuana", "Toluca"],
    "compras_realizadas" : [5, 12, 3, 29, 1, 7, 4, 15],
    "activo" : [True, False, True, True, False, True, False, True],
    "fecha_registro" : ["2026-01-10", "2026-01-12", "2026-02-10", "2026-02-12", "2026-01-05", "2026-02-05", "2026-02-07", "2026-01-07"]
}

# %%
df = pd.DataFrame(datos)

# %%
print(df)
# Out:
#     usuario  edad       ciudad  compras_realizadas  activo fecha_registro
# 0       Ana    22         CDMX                   5    True     2026-01-10
# 1      Luis    35    Monterrey                  12   False     2026-01-12
# 2    Martha    28  Guadalajara                   3    True     2026-02-10
# 3  Carolina    40       Puebla                  29    True     2026-02-12
# 4     Sofia    19       Cancún                   1   False     2026-01-05
# 5     Pedro    31       Merida                   7    True     2026-02-05
# 6     Elena    26      Tijuana                   4   False     2026-02-07
# 7     Diego    45       Toluca                  15    True     2026-01-07

# %%
df.head(3)
# Out:
#   usuario  edad       ciudad  compras_realizadas  activo fecha_registro
# 0     Ana    22         CDMX                   5    True     2026-01-10
# 1    Luis    35    Monterrey                  12   False     2026-01-12
# 2  Martha    28  Guadalajara                   3    True     2026-02-10

# %%
cantidad = 1000000

# %%
import random

# %%
nombres = ["Ana", "Luis", "Martha", "Carolina", "Sofia", "Pedro", "Elena", "Diego"]

# %%
cuidades = ["CDMX", "Monterrey", "Guadalajara", "Puebla", "Cancún", "Merida", "Tijuana", "Toluca"]

# %%
categorias = ["Tecnología", "Ropa", "Hogar", "Videojuegos", "Deportes", "Calzado", "comida", "Lacteos"]

# %%
dfMillion = pd.DataFrame ({
    "nombre" : [random.choice(nombres) for _ in range(cantidad)],
    "edad" : [random.randint(18,70) for _ in range(cantidad)],
    "salario" : [round(random.uniform(5000,50000),2) for _ in range(cantidad)],
    "activo" : [random.choice([True, False]) for _ in range(cantidad)],
    "categoria" : [random.choice(categorias) for _ in range(cantidad)],
    "ciudad" : [random.choice(cuidades) for _ in range(cantidad)],
    "anio_registro" : [random.randint(2020, 2026) for _ in range(cantidad)]
})

# %%
dfMillion.shape
# Out:
# (1000000, 7)

# %%
dfMillion.memory_usage(deep=True)
# Out:
# Index                 132
# nombre           54123835
# edad              8000000
# salario           8000000
# activo            1000000
# categoria        58260178
# ciudad           57865740
# anio_registro     8000000
# dtype: int64

# %%
dfMillion.memory_usage(deep=True).sum()/1014**2
# Out:
# 189.89558897330858
