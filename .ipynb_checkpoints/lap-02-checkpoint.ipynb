# %%
import pandas as pd

# %%
cantidad = 1000000

# %%
import random

# %%
influencer = ["Arqui Juve", "Paco Web", "Lupita TikTok", "Gilbertona", "Wendy Guevara", "Farid Dieck", "Fer_chusP"]

# %%
likes = [1,6,4,8,9,3,4]

# %%
comentarios = [
    "Me encantó el producto, llegó antes de lo esperado.",
    "La calidad no es buena por el precio que pagué.",
    "Excelente atención al cliente, resolvieron mi duda rápidamente.",
    "El envío tardó más de lo indicado, pero todo bien con el artículo.",
    "No volvería a comprar, la descripción no coincide con lo que recibí.",
    "Cumple su función, relación calidad-precio aceptable.",
    "Increíble, superó todas mis expectativas. Lo recomiendo 100%."
]

# %%
fechas = [
    "2025-10-15",
    "2024-03-22",
    "2025-07-01",
    "2024-11-09",
    "2025-12-25",
    "2024-06-18",
    "2025-01-30"
]

# %%
tipos_post = ["foto", "video", "foto", "video", "foto", "video", "foto"]

# %%
dfInfluencerIg = pd.DataFrame ({
    "Influencer" : [random.choice(influencer) for _ in range(cantidad)],
    "likes": [random.choice(likes) for _ in range(cantidad)],
    "comentarios": [random.choice(comentarios) for _ in range(cantidad)],
    "fechas": [random.choice(fechas) for _ in range(cantidad)],
})

# %%
dfInfluencerIg.shape
# Out:
# (1000000, 4)

# %%
dfInfluencerIg.dtypes
# Out:
# Influencer     object
# likes           int64
# comentarios    object
# fechas         object
# dtype: object

# %%
dfInfluencerIg.memory_usage(deep=True).sum()/1024**2
# Out:
# 238.4280366897583

# %%
df = pd.DataFrame(dfInfluencerIg)

# %%
print(df)
# Out:
#            Influencer  likes  \
# 0          Gilbertona      6
# 1       Lupita TikTok      4
# 2       Lupita TikTok      4
# 3       Wendy Guevara      4
# 4       Wendy Guevara      4
# ...               ...    ...
# 999995    Farid Dieck      3
# 999996  Wendy Guevara      1
# 999997  Wendy Guevara      4
# 999998      Fer_chusP      1
# 999999    Farid Dieck      9
#
#                                               comentarios      fechas
# 0       Cumple su función, relación calidad-precio ace...  2025-12-25
# 1       Cumple su función, relación calidad-precio ace...  2024-11-09
# 2       Me encantó el producto, llegó antes de lo espe...  2024-11-09
# 3         La calidad no es buena por el precio que pagué.  2025-01-30
# 4       El envío tardó más de lo indicado, pero todo b...  2025-12-25
# ...                                                   ...         ...
# 999995  No volvería a comprar, la descripción no coinc...  2025-12-25
# ...
